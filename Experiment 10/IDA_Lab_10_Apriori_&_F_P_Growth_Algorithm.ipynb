# %% [markdown]
# # Experiment 10
# ## Perform Comparative analysis of Apriori algorithm and FP - Growth algorithms on Market Basket Analysis using Python.

# %% [markdown]
# ## Shortcomings Of Apriori Algorithm
# Using Apriori needs a generation of candidate itemsets. These itemsets may be large in number if the itemset in the database is huge.
# Apriori needs multiple scans of the database to check the support of each itemset generated and this leads to high costs.
# These shortcomings can be overcome using the FP growth algorithm.
#
# ## Frequent Pattern Growth Algorithm
# This algorithm is an improvement to the Apriori method. A frequent pattern is generated without the need for candidate generation. FP growth algorithm represents the database in the form of a tree called a frequent pattern tree or FP tree.
#
# This tree structure will maintain the association between the itemsets. The database is fragmented using one frequent item. This fragmented part is called “pattern fragment”. The itemsets of these fragmented patterns are analyzed. Thus with this method, the search for frequent itemsets is reduced comparatively.
#
# ## FP Tree
# Frequent Pattern Tree is a tree-like structure that is made with the initial itemsets of the database. The purpose of the FP tree is to mine the most frequent pattern. Each node of the FP tree represents an item of the itemset.
#
# The root node represents null while the lower nodes represent the itemsets. The association of the nodes with the lower nodes that is the itemsets with the other itemsets are maintained while forming the tree.

# %% [markdown]
# ## Advantages Of FP Growth Algorithm
# 1. This algorithm needs to scan the database only twice when compared to Apriori which scans the transactions for each iteration.
# 2. The pairing of items is not done in this algorithm and this makes it faster.
# 3. The database is stored in a compact version in memory.
# 4. It is efficient and scalable for mining both long and short frequent patterns.
#
# ## Disadvantages Of FP-Growth Algorithm
# 1. FP Tree is more cumbersome and difficult to build than Apriori.
# 2. It may be expensive.
# 3. When the database is large, the algorithm may not fit in the shared memory.

# %% [markdown]
# ![Screenshot (27).png](data:image/png;base64,...)

# %% [markdown]
# ## Comparison of the **Apriori** algorithm and the **FP-Growth** algorithm, both of which are commonly used for frequent itemset mining in market basket analysis:
#
# 1. **Apriori Algorithm**:
#    - **Join-Based Algorithm**: The Apriori algorithm generates candidate itemsets by joining and pruning based on the **apriori property**.
#    - **Methodology**:
#      - Initially, it scans the database to find frequent single items (itemsets with high support).
#      - Then, it generates candidate itemsets of size 2 by joining frequent single items.
#      - It continues this process iteratively to find larger itemsets.
#      - Pruning is done to eliminate candidates that violate the apriori property (i.e., if a subset of an itemset is not frequent, the itemset itself cannot be frequent).
#    - **Pros**:
#      - Simple and easy to understand.
#      - Guarantees completeness (finds all frequent itemsets).
#    - **Cons**:
#      - Requires multiple passes over the data.
#      - Generates a large number of candidate itemsets.
#      - Can be computationally expensive.
#
# 2. **FP-Growth Algorithm**:
#    - **Tree-Based Algorithm**: FP-Growth constructs an **FP-tree** to represent the dataset efficiently.
#    - **Methodology**:
#      - It scans the database once to build the FP-tree.
#      - The FP-tree compresses frequent items into a compact structure.
#      - It then recursively mines frequent itemsets from the FP-tree.
#      - No candidate generation step is needed.
#    - **Pros**:
#      - Requires only two passes over the data (building the FP-tree and mining frequent itemsets).
#      - Efficient for large datasets.
#      - Reduces memory usage.
#    - **Cons**:
#      - May not be as intuitive as Apriori.
#      - Tree construction can be complex.
#
# 3. **Comparing Apriori and FP-Growth**:
#    - **Efficiency**:
#      - Apriori: Multiple passes over the data, candidate generation.
#      - FP-Growth: Single pass, no candidate generation.
#    - **Memory Usage**:
#      - Apriori: Requires more memory due to candidate generation.
#      - FP-Growth: Compact FP-tree reduces memory usage.
#    - **Complexity**:
#      - Apriori: Simpler to understand.
#      - FP-Growth: Requires understanding of tree-based structures.
#    - **Performance**:
#      - Apriori: Slower for large datasets.
#      - FP-Growth: Faster and more efficient.
#
# In summary, **FP-Growth** is often preferred for its efficiency and reduced memory usage, especially when dealing with large datasets.

# %%
# !pip install fpgrowth_py
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# ...

# %%
# For ignoring warnings
import warnings
warnings.simplefilter("ignore")
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
# Importing required libraries
import pandas as pd
from fpgrowth_py import fpgrowth

# %%
# Reading CSV file
data = pd.read_csv("Market_Basket_Optimisation.csv", na_filter=False)
print("Dataset is:\n",data.head(n=6))

# We need to give dataframe in a tabular format with True and False
# Converting to numpy array so that we can later convert to Boolean Values
data = data.to_numpy()
print("\nDataset after converting to Numpy Array is:\n",data)
# Out:
# Dataset is:
#                shrimp       almonds     avocado    vegetables mix green grapes  \
# 0            burgers     meatballs        eggs
# 1            chutney
# 2             turkey       avocado
# 3      mineral water          milk  energy bar  whole wheat rice    green tea
# 4     low fat yogurt
# 5  whole wheat pasta  french fries
#
#   whole weat flour yams cottage cheese energy drink tomato juice  \
# 0
# 1
# 2
# 3
# 4
# 5
#
#   low fat yogurt green tea honey salad mineral water salmon antioxydant juice  \
# 0
# 1
# 2
# 3
# 4
# 5
#
#   frozen smoothie spinach olive oil
# 0
# 1
# 2
# 3
# 4
# 5
#
# Dataset after converting to Numpy Array is:
#  [['burgers' 'meatballs' 'eggs' ... '' '' '']
#  ['chutney' '' '' ... '' '' '']
#  ['turkey' 'avocado' '' ... '' '' '']
#  ...
#  ['chicken' '' '' ... '' '' '']
#  ['escalope' 'green tea' '' ... '' '' '']
#  ['eggs' 'frozen smoothie' 'yogurt cake' ... '' '' '']]

# %%
from fpgrowth_py import fpgrowth

itemSetList = data

freqItemSet, rules = fpgrowth(itemSetList, minSupRatio=0.1, minConf=0.1)
print("Frequent Itemsets in Data are:\n")
print(freqItemSet)
print("\nSupport Values Calculated are:\n")
print(rules)
# Out:
# Frequent Itemsets in Data are:
#
# ...
